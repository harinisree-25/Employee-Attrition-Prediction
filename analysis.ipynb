# %% [markdown]
# # Employee Attrition Analysis
#
# Starter notebook for exploring the HR employee attrition dataset.

# %%
import pandas as pd

data_path = "WA_Fn-UseC_-HR-Employee-Attrition.csv"
df = pd.read_csv(data_path)
df.head()
